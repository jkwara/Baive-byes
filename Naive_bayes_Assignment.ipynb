# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-74ba6e9f-466b-4e59-95ea-49768c85b10b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-74ba6e9f-466b-4e59-95ea-49768c85b10b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_train = pd.read_csv("SalaryData_Train.csv")

# %%
df_train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
df_train.info()
# check the data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
dr_train = df_train[df_train.duplicated()]
#checking the duplicates values same data entered again

# %%
dr_train
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 326     33   Private      Bachelors           13   Married-civ-spouse
# 364     27   Private      Bachelors           13        Never-married
# 518     24   Private        HS-grad            9        Never-married
# 525     24   Private        HS-grad            9        Never-married
# 619     33   Private      Bachelors           13   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 30110   47   Private        HS-grad            9   Married-civ-spouse
# 30118   20   Private        HS-grad            9        Never-married
# 30132   22   Private   Some-college           10        Never-married
# 30157   40   Private        HS-grad            9   Married-civ-spouse
# 30159   22   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# ...

# %%
df_train.drop_duplicates(keep=False,inplace=True)
#dropthe duplicate values

# %%
df_train.shape
# Out:
# (24943, 14)

# %%
df_train["workclass"].value_counts()
# Out:
#  Private             17416
#  Self-emp-not-inc     2377
#  Local-gov            1966
#  State-gov            1228
#  Self-emp-inc         1027
#  Federal-gov           915
#  Without-pay            14
# Name: workclass, dtype: int64

# %%
df_train.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ed1632da-bf30-40a8-a4fd-a544de3bcd9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed1632da-bf30-40a8-a4fd-a544de3bcd9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_test = pd.read_csv("SalaryData_Test.csv")

# %%
df_test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
dr_test = df_test[df_test.duplicated()]

# %%
dr_test
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 551     59   Private        HS-grad            9             Divorced
# 601     32   Private        HS-grad            9   Married-civ-spouse
# 681     40   Private        HS-grad            9   Married-civ-spouse
# 799     24   Private      Bachelors           13        Never-married
# 1044    44   Private    Prof-school           15   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 15043   51   Private        HS-grad            9   Married-civ-spouse
# 15044   22   Private   Some-college           10        Never-married
# 15049   32   Private        HS-grad            9   Married-civ-spouse
# 15052   31   Private        HS-grad            9   Married-civ-spouse
# 15053   25   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# ...

# %%
df_test.drop_duplicates(keep=False,inplace=True)

# %%
df_test.shape
# Out:
# (13450, 14)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
object_col = df_train.select_dtypes("object")
object_col
# filter the catagerical/strings columns from the data frame
# Out:
#                workclass      education        maritalstatus  \
# 0              State-gov      Bachelors        Never-married
# 1       Self-emp-not-inc      Bachelors   Married-civ-spouse
# 2                Private        HS-grad             Divorced
# 3                Private           11th   Married-civ-spouse
# 4                Private      Bachelors   Married-civ-spouse
# ...                  ...            ...                  ...
# 30154            Private        Masters   Married-civ-spouse
# 30155            Private   Some-college        Never-married
# 30156            Private     Assoc-acdm   Married-civ-spouse
# 30158            Private        HS-grad              Widowed
# 30160       Self-emp-inc        HS-grad   Married-civ-spouse
#
#                occupation    relationship    race      sex          native  \
# 0            Adm-clerical   Not-in-family   White     Male   United-States
# 1         Exec-managerial         Husband   White     Male   United-States
# ...

# %%
for i in object_col:
  df_train[i] = label_encoder.fit_transform(df_train[i])
# convert catogery to numeric

# %%
df_train.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   39          5          9           13              4           0
# 1   50          4          9           13              2           3
# 2   38          2         11            9              0           5
# 3   53          2          1            7              2           5
# 4   28          2          9           13              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1         2174            0            40      37
# 1             0     4    1            0            0            13      37
# 2             1     4    1            0            0            40      37
# 3             0     2    1            0            0            40      37
# 4             5     2    0            0            0            40       4
#
#    Salary
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
for i in object_col:
  df_test[i] = label_encoder.fit_transform(df_test[i])

# %%
df_test.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   25          2          1            7              4           6
# 1   38          2         11            9              2           4
# 2   28          1          7           12              2          10
# 3   44          2         15           10              2           6
# 4   34          2          0            6              4           7
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             3     2    1            0            0            40      37
# 1             0     4    1            0            0            50      37
# 2             0     4    1            0            0            40      37
# 3             0     2    1         7688            0            40      37
# 4             1     4    1            0            0            30      37
#
#    Salary
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0

# %%
x_test = df_test.drop(["Salary"],axis=1)

# %%
y_test = df_test["Salary"]

# %%
x_test.sample()
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 12306   46          2          9           13              4           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# 12306             1     1    1            0            0            40      28

# %%
y_test.sample()
# Out:
# 14009    0
# Name: Salary, dtype: int64

# %%
x_train = df_train.drop(["Salary"],axis=1)

# %%
y_train = df_train["Salary"]

# %%
x_train.sample()
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 24822   42          2          1            7              0           2
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# 24822             1     4    1            0            0            40      37

# %%
y_train.sample()
# Out:
# 13305    1
# Name: Salary, dtype: int64

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# checking the test and train data row and columns
# Out:
# ((24943, 13), (24943,), (13450, 13), (13450,))

# %%
y_train.value_counts()
# the data is imbalanced
# Out:
# 0    18486
# 1     6457
# Name: Salary, dtype: int64

# %% [markdown]
# checking the feature importances

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# ExtraTreesClassifier()

# %%
model.feature_importances_
# Out:
# array([0.21493829, 0.05346601, 0.03562359, 0.08787496, 0.06878405,
#        0.08942497, 0.10580266, 0.01807914, 0.03049842, 0.10956269,
#        0.03460201, 0.13077355, 0.02056966])

# %%
feature_imp = pd.Series(model.feature_importances_,index=x_train.columns)

# %%
feature_imp
#important features for predict y
# Out:
# age              0.214938
# workclass        0.053466
# education        0.035624
# educationno      0.087875
# maritalstatus    0.068784
# occupation       0.089425
# relationship     0.105803
# race             0.018079
# sex              0.030498
# capitalgain      0.109563
# capitalloss      0.034602
# hoursperweek     0.130774
# native           0.020570
# dtype: float64

# %%
feature_imp.sort_values(ascending=False)
# Out:
# age              0.214938
# hoursperweek     0.130774
# capitalgain      0.109563
# relationship     0.105803
# occupation       0.089425
# educationno      0.087875
# maritalstatus    0.068784
# workclass        0.053466
# education        0.035624
# capitalloss      0.034602
# sex              0.030498
# native           0.020570
# race             0.018079
# dtype: float64

# %%
sns.barplot(x=feature_imp.sort_values(ascending=False),y=x_train.columns)
plt.xlabel("Feature Importan Score",size=10,color="r")
plt.ylabel("Features",size=10,color="r")
plt.title("Important Features")
# Out:
# Text(0.5, 1.0, 'Important Features')

# %%
df_train.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  30161.000000  30161.000000  30161.000000  30161.000000  30161.000000
# mean      38.438115     10.121316   1092.044064     88.302311     40.931269
# std       13.134830      2.550037   7406.466611    404.121321     11.980182
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
n_c = df_train.select_dtypes("int")
#  select the numerical columns

# %%
sns.distplot(n_c["educationno"])
sns.distplot(n_c["age"])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   39          5          9           13              4           0
# 1   50          4          9           13              2           3
# 2   38          2         11            9              0           5
# 3   53          2          1            7              2           5
# 4   28          2          9           13              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# 0             1     4    1         2174            0            40      37
# 1             0     4    1            0            0            13      37
# 2             1     4    1            0            0            40      37
# 3             0     2    1            0            0            40      37
# 4             5     2    0            0            0            40       4

# %%
scaler.fit(x_train[n_c.columns])
# Out:
# StandardScaler()

# %%
x_train[n_c.columns]=scaler.transform(x_train[n_c.columns])

# %%
x_train.head()
# Out:
#         age  workclass  education  educationno  maritalstatus  occupation  \
# 0 -0.032827          5          9     1.069828              4           0
# 1  0.799379          4          9     1.069828              2           3
# 2 -0.108483          2         11    -0.432373              0           5
# 3  1.026344          2          1    -1.183474              2           5
# 4 -0.865034          2          9     1.069828              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# 0             1     4    1     0.107996    -0.240017     -0.101894      37
# 1             0     4    1    -0.161349    -0.240017     -2.246120      37
# 2             1     4    1    -0.161349    -0.240017     -0.101894      37
# 3             0     2    1    -0.161349    -0.240017     -0.101894      37
# 4             5     2    0    -0.161349    -0.240017     -0.101894       4

# %%
scaler.fit(x_test[n_c.columns])
# Out:
# StandardScaler()

# %%
x_test[n_c.columns] = scaler.transform(x_test[n_c.columns])

# %%
x_test.head()
# Out:
#         age  workclass  education  educationno  maritalstatus  occupation  \
# 0 -1.074581          2          1    -1.184288              4           6
# 1 -0.108389          2         11    -0.424912              2           4
# 2 -0.851614          1          7     0.714152              2          10
# 3  0.337546          2         15    -0.045224              2           6
# 4 -0.405679          2          0    -1.563976              4           7
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# 0             3     2    1    -0.153696    -0.231697     -0.093292      37
# 1             0     4    1    -0.153696    -0.231697      0.712037      37
# 2             0     4    1    -0.153696    -0.231697     -0.093292      37
# 3             0     2    1     0.801292    -0.231697     -0.093292      37
# 4             1     4    1    -0.153696    -0.231697     -0.898622      37

# %% [markdown]
# Naive Bayes Model

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB

# %%
model = GaussianNB()
#using gaussian navie bayes if feature is continuous and normal distribution

# %%
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_predict = model.predict(x_test)

# %%
y_predict
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_predict))

print("--*--*"*50)

print("1) Imbalanced Data Accuracy Does not help")
print('  ')
print(" 2) The model is better at predicting class 0 (higher precision and recall) compared to class 1.")
print(" ")
print(" 3) Class 1 has a lower recall, indicating that the model is not as effective at capturing all the actual class 1")
print(" ")
print(" 4) The weighted average F1-score is 0.77, indicating a decent overall performance of the model.")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87     10093
#            1       0.68      0.35      0.47      3357
#
#     accuracy                           0.80     13450
#    macro avg       0.75      0.65      0.67     13450
# weighted avg       0.78      0.80      0.77     13450
#
# --*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*
# 1) Imbalanced Data Accuracy Does not help
#
#  2) The model is better at predicting class 0 (higher precision and recall) compared to class 1.
#
#  3) Class 1 has a lower recall, indicating that the model is not as effective at capturing all the actual class 1
#
# ...
